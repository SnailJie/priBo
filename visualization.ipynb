# %%
from bayes_opt import BayesianOptimization
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

# plt.style.use(['dark_background'])

# %%
def target(x,y):
    return x+y

# %% [markdown]
# # Create a BayesianOptimization Object
#
# Enter the target function to be maximized, its variable(s) and their corresponding ranges (see this [example](https://github.com/fmfn/BayesianOptimization/blob/master/examples/usage.py) for a multi-variable case). A minimum number of 2 initial guesses is necessary to kick start the algorithms, these can either be random or user defined.

# %%
bo = BayesianOptimization(target, {'x': (-2, 10),'y':(11,14)})

# %% [markdown]
# In this example we will use the Upper Confidence Bound (UCB) as our utility function. It has the free parameter
# $\kappa$ which control the balance between exploration and exploitation; we will set $\kappa=5$ which, in this case, makes the algorithm quite bold. Additionally we will use the cubic correlation in our Gaussian Process.

# %%
bo.maximize(init_points=2, n_iter=0, acq='ei', kappa=5)
# Out:
# Initialization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |
#     1 | 00m00s |   14.00000 |    2.0000 |   12.0000 |
#     2 | 00m00s |   10.00000 |   -1.0000 |   11.0000 |
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# acq_max中返回的最大值为:
#
# [ 2. 12.]
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |

# %% [markdown]
# ### Two random points
#
# After we probe two points at random, we can fit a Gaussian Process and start the bayesian optimization procedure. Two points should give us a uneventful posterior with the uncertainty growing as we go further from the observations.

# %% [markdown]
# ### After one step of GP (and two random points)

# %%
bo.maximize(init_points=0, n_iter=1, kappa=5)
# Out:
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# acq_max中返回的最大值为:
#
# [ 2. 13.]
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |
#     3 | 00m02s |   15.00000 |    2.0000 |   13.0000 |
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# acq_max中返回的最大值为:
#
# [ 1. 14.]

# %% [markdown]
# ### After two steps of GP (and two random points)

# %%
bo.maximize(init_points=0, n_iter=1, kappa=5)
# Out:
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# acq_max中返回的最大值为:
#
# [ 1. 14.]
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |
#     4 | 00m02s |   15.00000 |    1.0000 |   14.0000 |
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# acq_max中返回的最大值为:
#
# [ 2. 14.]

# %% [markdown]
# ### After three steps of GP (and two random points)

# %%
bo.maximize(init_points=0, n_iter=1, kappa=5)
# Out:
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# acq_max中返回的最大值为:
#
# [ 2. 14.]
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |
#     5 | 00m02s |   16.00000 |    2.0000 |   14.0000 |
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# 更新x——max
#
# acq_max中返回的最大值为:
#
# [ 3. 14.]

# %% [markdown]
# ### After four steps of GP (and two random points)

# %%
bo.maximize(init_points=0, n_iter=1, kappa=5)
# Out:
# acq_max中返回的最大值为:
#
# [10. 14.]
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |
#     6 | 00m06s |   19.00000 |    7.0000 |   12.0000 | Warning: Test point chose at random due to repeated sample.
#
# acq_max中返回的最大值为:
#
# [10. 14.]

# %% [markdown]
# ### After five steps of GP (and two random points)

# %%
bo.maximize(init_points=0, n_iter=1, kappa=5)
# Out:
# 更新x_max为
# [14.  9.]
# 更新x_max为
# [14.  9.]
# 更新x_max为
# [14.  9.]
# 更新x_max为
# [14.  9.]
# acq_max中返回的最大值为:
#
# [14.  9.]
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |
#     5 | 00m02s |   23.00000 |    9.0000 |   14.0000 |
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# acq_max中返回的最大值为:
#
# [14. 10.]

# %% [markdown]
# ### After six steps of GP (and two random points)

# %%
bo.maximize(init_points=0, n_iter=1, kappa=5)
# Out:
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# acq_max中返回的最大值为:
#
# [14. 10.]
# Bayesian Optimization
# -----------------------------------------------------
#  Step |   Time |      Value |         x |         y |
#     6 | 00m01s |   24.00000 |   10.0000 |   14.0000 |
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# 更新x_max为
# [14. 10.]
# acq_max中返回的最大值为:
#
# [14. 10.]

# %% [markdown]
# ### After seven steps of GP (and two random points)

# %%
bo.maximize(init_points=0, n_iter=1, kappa=5)
plot_gp(bo, x, y)
# Out:
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     9 | 00m02s |    0.84665 |    3.0526 |

# %% [markdown]
# # Stopping
#
# After just a few points the algorithm was able to get pretty close to the true maximum. It is important to notice that the trade off between exploration (exploring the parameter space) and exploitation (probing points near the current known maximum) is fundamental to a succesful bayesian optimization procedure. The utility function being used here (Upper Confidence Bound - UCB) has a free parameter $\kappa$ that allows the user to make the algorithm more or less conservative. Additionally, a the larger the initial set of random points explored, the less likely the algorithm is to get stuck in local minima due to being too conservative.
